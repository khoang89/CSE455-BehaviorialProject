# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# Classic Imports.

# %%
directory = '/kaggle/input/state-farm-distracted-driver-detection/imgs/train'

image_dataset = torchvision.datasets.ImageFolder(directory, transforms.Compose([
    transforms.Resize(224),
    transforms.RandomHorizontalFlip(),    # 50% of time flip image along y-axis
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
]))

# %% [markdown]
# We resize to 224 px and normalize with the mean and std_dev, to follow the standard practice of ResNet. We have a random horizontal flip to ensure that we don't overfit.

# %%
print(len(image_dataset))
# Out:
# 22424

# %% [markdown]
# I couldn't find a place on Kaggle that listed how many training images there were off the bat, so I'm printing here to find out. There are 22,424 photos. I am using the training dataset as my overall dataset to split into training, testing, and validation sets because my previous code (from the mask project) is already optimized for this format and I won't have to cross reference the .csv file.

# %%
key = {"c0": "safe driving",
"c1": "texting - right",
"c2": "talking on the phone - right",
"c3": "texting - left",
"c4": "talking on the phone - left",
"c5": "operating the radio",
"c6": "drinking",
"c7": "reaching behind",
"c8": "hair and makeup",
"c9": "talking to passenger"}

# %% [markdown]
# We make a key for quick label translation.

# %%
import math
testing_split = math.floor(0.1 * len(image_dataset))
print(testing_split)
validation_split = math.floor(0.1 * len(image_dataset))
print(validation_split)
training_split = len(image_dataset) - (testing_split + validation_split)
print(training_split)
# Out:
# 2242
# 2242
# 17940

# %% [markdown]
# We use a standard 80-10-10 split for training, test, and validation. We make our own training, test, and validation sets for the reason specified above.
#
# Above: "my previous code (from the mask project) is already optimized for this format and I won't have to cross reference the .csv file"

# %%
train_set, test_set, val_set = torch.utils.data.random_split(image_dataset, [training_split, testing_split, validation_split])
trainloader = torch.utils.data.DataLoader(train_set, batch_size=8, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(test_set, batch_size=4, shuffle=False, num_workers=2)
valloader = torch.utils.data.DataLoader(val_set, batch_size=8, shuffle=False, num_workers=2)

# %% [markdown]
# Let's load our data.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)

# %% [markdown]
# Our imshow method, taking into account the previous mean and std values for Resnet training.

# %%
class_names = train_set.dataset.classes
print(class_names)
# Out:
# ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# %% [markdown]
# Let's see what labels we have.

# %%
dataiter = iter(trainloader)
images, classes = next(dataiter)
images = images[:4]
print(images.size())
imshow(torchvision.utils.make_grid(images), title=[key.get(class_names[x]) for x in classes[:4]])
plt.savefig('ExampleFig.png')
# Out:
# torch.Size([4, 3, 224, 298])

# %% [markdown]
# Just a quick check to see that we are training on valid data and that our labels are accurate.

# %%
import copy
def train(net, trainloader, valloader, epochs=1, start_epoch=0, lr=0.01, momentum=0.9, decay=0.0005, 
          verbose=1, print_every=10, state=None, schedule={}, checkpoint_path=None):
    net.to(device)
    net.train()
    
    best_accuracy = 0.0 # Keep track of the best performing model every epoch
    best_wts = copy.deepcopy(net.state_dict()) # Record best performing model parameters
    
    training_losses = []
    training_accuracy = []
    val_losses = []
    val_accuracy = []
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr/50, momentum=momentum, weight_decay=decay)
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=lr, steps_per_epoch=len(trainloader), epochs=epochs, div_factor=50, final_div_factor=5000, verbose=verbose)
    
    # Fast forward lr schedule through already trained epochs
    for epoch in range(start_epoch):
        if epoch in schedule:
            print ("Learning rate: %f"% schedule[epoch])
            for g in optimizer.param_groups:
                g['lr'] = schedule[epoch]

    for epoch in range(start_epoch, epochs):
        for phase in ["train", "val"]: # Two phase process for Validation
            sum_loss = 0.0
            sum_correct = 0.0
            if phase == "train":   # Standard minibatch SGD like previous train methods
                dataloader = trainloader
                losses = training_losses
                accuracy = training_accuracy
           
                for i, batch in enumerate(dataloader, 0):
                    inputs, labels = batch[0].to(device), batch[1].to(device)

                    optimizer.zero_grad()

                    outputs = net(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    loss.backward()  # autograd magic, computes all the partial derivatives
                    optimizer.step() # takes a step in gradient direction

                    losses.append(loss.item()) # Total loss per minibatch is recorded
                    accuracy.append(torch.sum(preds == labels.data) / 8) # Accuracy per minibatch
                    
                    sum_loss += loss.item()
                    sum_correct += torch.sum(preds == labels.data)

                    scheduler.step()

                    if i % print_every == print_every-1:    # print every 10 mini-batches
                        if verbose:
                             # Print average total training loss every over 10 minibatches
                            print(str(phase) + ' [%d, %5d] loss: %.3f' % (epoch, i + 1, sum_loss / print_every))
                            # Print average accuracy percentage every 10 minibatches.
                            print(str(phase) + ' [%d, %5d] acc: %.3f' % (epoch, i + 1, sum_correct / (print_every * 8))) 
                            
                        sum_loss = 0.0
                        sum_correct = 0.0
            else: # Our new validation phase
                dataloader = valloader
                losses = val_losses
                accuracy = val_accuracy 
                for i, batch in enumerate(dataloader, 0):
                    inputs, labels = batch[0].to(device), batch[1].to(device)

                    optimizer.zero_grad()

                    outputs = net(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    sum_loss += loss.item()
                    sum_correct += torch.sum(preds == labels.data)

                # Data is recorded and printed out per epoch. 
                # Total loss and accuracy per epoch is recorded computed over the entire validation dataset.
                epoch_accuracy = sum_correct / validation_split
                losses.append(sum_loss)
                accuracy.append(epoch_accuracy)
                print(str(phase) + ' %d loss: %.3f' % (epoch, sum_loss))
                print(str(phase) + ' %d acc: %.3f' % (epoch,  epoch_accuracy))
                
                # Check if performs better than previous epoch
                if epoch_accuracy > best_accuracy:
                    best_accuracy = epoch_accuracy
                    best_wts = copy.deepcopy(net.state_dict())
        if checkpoint_path:
            state = {'epoch': epoch+1, 'net': net.state_dict(), 'optimizer': optimizer.state_dict(), 'training losses': training_losses, 'training accuracy': training_accuracy, "validation losses" : val_losses, "validation accuracy" : val_accuracy}
            torch.save(state, checkpoint_path + 'checkpoint-%d.pkl'%(epoch+1))
    print(f'Best validation accuracy: {best_accuracy:4f}')
    net.load_state_dict(best_wts)
    return net, training_losses, training_accuracy, val_losses, val_accuracy

# %% [markdown]
# This training method is based on the original training method in the Bird Classification shown in class. However, it has been modified to take into account for a validation phase and to calculate average accuracy per phase. Notice the difference in the data we record and print (for training, loss and accuracy are recorded per batch, but for training print out, the losses and accuracy statistics are the average of 10 minibatches. For validation, training loss and accuracy data is recorded and printed out per epoch.

# %%
resnet = torch.hub.load('pytorch/vision:v0.6.0', 'resnet18', pretrained=True)
num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, len(class_names))
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.6.0" to /root/.cache/torch/hub/v0.6.0.zip
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 239MB/s]

# %% [markdown]
# Let's import resnet for our transfer learning.

# %%
resnet, training_losses, training_accuracy, val_losses, val_accuracy = train(resnet, trainloader, valloader, epochs=10, lr=.05, print_every=10, checkpoint_path='./')
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0001e-03.
# Adjusting learning rate of group 0 to 1.0001e-03.
# Adjusting learning rate of group 0 to 1.0001e-03.
# Adjusting learning rate of group 0 to 1.0002e-03.
# Adjusting learning rate of group 0 to 1.0002e-03.
# Adjusting learning rate of group 0 to 1.0003e-03.
# train [0,    10] loss: 2.386
# train [0,    10] acc: 0.163
# Adjusting learning rate of group 0 to 1.0003e-03.
# Adjusting learning rate of group 0 to 1.0004e-03.
# Adjusting learning rate of group 0 to 1.0005e-03.
# Adjusting learning rate of group 0 to 1.0005e-03.
# Adjusting learning rate of group 0 to 1.0006e-03.
# Adjusting learning rate of group 0 to 1.0007e-03.
# Adjusting learning rate of group 0 to 1.0008e-03.
# Adjusting learning rate of group 0 to 1.0009e-03.
# Adjusting learning rate of group 0 to 1.0010e-03.
# Adjusting learning rate of group 0 to 1.0011e-03.
# train [0,    20] loss: 2.364
# train [0,    20] acc: 0.150
# Adjusting learning rate of group 0 to 1.0012e-03.
# Adjusting learning rate of group 0 to 1.0013e-03.
# Adjusting learning rate of group 0 to 1.0014e-03.
# Adjusting learning rate of group 0 to 1.0015e-03.
# Adjusting learning rate of group 0 to 1.0017e-03.
# Adjusting learning rate of group 0 to 1.0018e-03.
# Adjusting learning rate of group 0 to 1.0019e-03.
# Adjusting learning rate of group 0 to 1.0021e-03.
# Adjusting learning rate of group 0 to 1.0022e-03.
# Adjusting learning rate of group 0 to 1.0024e-03.
# train [0,    30] loss: 2.221
# train [0,    30] acc: 0.263
# Adjusting learning rate of group 0 to 1.0026e-03.
# Adjusting learning rate of group 0 to 1.0027e-03.
# Adjusting learning rate of group 0 to 1.0029e-03.
# Adjusting learning rate of group 0 to 1.0031e-03.
# Adjusting learning rate of group 0 to 1.0033e-03.
# Adjusting learning rate of group 0 to 1.0035e-03.
# Adjusting learning rate of group 0 to 1.0037e-03.
# Adjusting learning rate of group 0 to 1.0039e-03.
# Adjusting learning rate of group 0 to 1.0041e-03.
# Adjusting learning rate of group 0 to 1.0043e-03.
# train [0,    40] loss: 2.146
# train [0,    40] acc: 0.188
# Adjusting learning rate of group 0 to 1.0045e-03.
# Adjusting learning rate of group 0 to 1.0047e-03.
# Adjusting learning rate of group 0 to 1.0049e-03.
# Adjusting learning rate of group 0 to 1.0052e-03.
# Adjusting learning rate of group 0 to 1.0054e-03.
# Adjusting learning rate of group 0 to 1.0057e-03.
# Adjusting learning rate of group 0 to 1.0059e-03.
# Adjusting learning rate of group 0 to 1.0062e-03.
# Adjusting learning rate of group 0 to 1.0064e-03.
# Adjusting learning rate of group 0 to 1.0067e-03.
# train [0,    50] loss: 2.146
# train [0,    50] acc: 0.237
# Adjusting learning rate of group 0 to 1.0069e-03.
# Adjusting learning rate of group 0 to 1.0072e-03.
# Adjusting learning rate of group 0 to 1.0075e-03.
# Adjusting learning rate of group 0 to 1.0078e-03.
# Adjusting learning rate of group 0 to 1.0081e-03.
# Adjusting learning rate of group 0 to 1.0084e-03.
# Adjusting learning rate of group 0 to 1.0087e-03.
# Adjusting learning rate of group 0 to 1.0090e-03.
# Adjusting learning rate of group 0 to 1.0093e-03.
# Adjusting learning rate of group 0 to 1.0096e-03.
# train [0,    60] loss: 1.899
# train [0,    60] acc: 0.400
# Adjusting learning rate of group 0 to 1.0099e-03.
# Adjusting learning rate of group 0 to 1.0103e-03.
# Adjusting learning rate of group 0 to 1.0106e-03.
# Adjusting learning rate of group 0 to 1.0109e-03.
# Adjusting learning rate of group 0 to 1.0113e-03.
# Adjusting learning rate of group 0 to 1.0116e-03.
# Adjusting learning rate of group 0 to 1.0120e-03.
# Adjusting learning rate of group 0 to 1.0123e-03.
# Adjusting learning rate of group 0 to 1.0127e-03.
# Adjusting learning rate of group 0 to 1.0131e-03.
# train [0,    70] loss: 1.769
# train [0,    70] acc: 0.412
# Adjusting learning rate of group 0 to 1.0135e-03.
# Adjusting learning rate of group 0 to 1.0138e-03.
# Adjusting learning rate of group 0 to 1.0142e-03.
# Adjusting learning rate of group 0 to 1.0146e-03.
# Adjusting learning rate of group 0 to 1.0150e-03.
# Adjusting learning rate of group 0 to 1.0154e-03.
# Adjusting learning rate of group 0 to 1.0158e-03.
# Adjusting learning rate of group 0 to 1.0162e-03.
# Adjusting learning rate of group 0 to 1.0167e-03.
# Adjusting learning rate of group 0 to 1.0171e-03.
# train [0,    80] loss: 1.680
# train [0,    80] acc: 0.500
# Adjusting learning rate of group 0 to 1.0175e-03.
# Adjusting learning rate of group 0 to 1.0180e-03.
# Adjusting learning rate of group 0 to 1.0184e-03.
# Adjusting learning rate of group 0 to 1.0188e-03.
# Adjusting learning rate of group 0 to 1.0193e-03.
# Adjusting learning rate of group 0 to 1.0198e-03.
# Adjusting learning rate of group 0 to 1.0202e-03.
# Adjusting learning rate of group 0 to 1.0207e-03.
# Adjusting learning rate of group 0 to 1.0212e-03.
# Adjusting learning rate of group 0 to 1.0216e-03.
# train [0,    90] loss: 1.376
# train [0,    90] acc: 0.512
# Adjusting learning rate of group 0 to 1.0221e-03.
# Adjusting learning rate of group 0 to 1.0226e-03.
# Adjusting learning rate of group 0 to 1.0231e-03.
# Adjusting learning rate of group 0 to 1.0236e-03.
# Adjusting learning rate of group 0 to 1.0241e-03.
# Adjusting learning rate of group 0 to 1.0246e-03.
# Adjusting learning rate of group 0 to 1.0251e-03.
# Adjusting learning rate of group 0 to 1.0256e-03.
# Adjusting learning rate of group 0 to 1.0262e-03.
# Adjusting learning rate of group 0 to 1.0267e-03.
# train [0,   100] loss: 1.196
# train [0,   100] acc: 0.675
# Adjusting learning rate of group 0 to 1.0272e-03.
# Adjusting learning rate of group 0 to 1.0278e-03.
# Adjusting learning rate of group 0 to 1.0283e-03.
# Adjusting learning rate of group 0 to 1.0289e-03.
# Adjusting learning rate of group 0 to 1.0294e-03.
# Adjusting learning rate of group 0 to 1.0300e-03.
# Adjusting learning rate of group 0 to 1.0306e-03.
# Adjusting learning rate of group 0 to 1.0311e-03.
# Adjusting learning rate of group 0 to 1.0317e-03.
# Adjusting learning rate of group 0 to 1.0323e-03.
# train [0,   110] loss: 1.284
# train [0,   110] acc: 0.613
# Adjusting learning rate of group 0 to 1.0329e-03.
# Adjusting learning rate of group 0 to 1.0335e-03.
# Adjusting learning rate of group 0 to 1.0341e-03.
# Adjusting learning rate of group 0 to 1.0347e-03.
# Adjusting learning rate of group 0 to 1.0353e-03.
# Adjusting learning rate of group 0 to 1.0359e-03.
# Adjusting learning rate of group 0 to 1.0366e-03.
# Adjusting learning rate of group 0 to 1.0372e-03.
# Adjusting learning rate of group 0 to 1.0378e-03.
# Adjusting learning rate of group 0 to 1.0385e-03.
# train [0,   120] loss: 1.077
# train [0,   120] acc: 0.588
# Adjusting learning rate of group 0 to 1.0391e-03.
# Adjusting learning rate of group 0 to 1.0397e-03.
# Adjusting learning rate of group 0 to 1.0404e-03.
# Adjusting learning rate of group 0 to 1.0411e-03.
# Adjusting learning rate of group 0 to 1.0417e-03.
# Adjusting learning rate of group 0 to 1.0424e-03.
# Adjusting learning rate of group 0 to 1.0431e-03.
# Adjusting learning rate of group 0 to 1.0437e-03.
# Adjusting learning rate of group 0 to 1.0444e-03.
# Adjusting learning rate of group 0 to 1.0451e-03.
# train [0,   130] loss: 0.684
# train [0,   130] acc: 0.812
# Adjusting learning rate of group 0 to 1.0458e-03.
# Adjusting learning rate of group 0 to 1.0465e-03.
# Adjusting learning rate of group 0 to 1.0472e-03.
# Adjusting learning rate of group 0 to 1.0479e-03.
# Adjusting learning rate of group 0 to 1.0487e-03.
# Adjusting learning rate of group 0 to 1.0494e-03.
# Adjusting learning rate of group 0 to 1.0501e-03.
# Adjusting learning rate of group 0 to 1.0508e-03.
# Adjusting learning rate of group 0 to 1.0516e-03.
# Adjusting learning rate of group 0 to 1.0523e-03.
# train [0,   140] loss: 0.795
# train [0,   140] acc: 0.750
# Adjusting learning rate of group 0 to 1.0531e-03.
# Adjusting learning rate of group 0 to 1.0538e-03.
# Adjusting learning rate of group 0 to 1.0546e-03.
# Adjusting learning rate of group 0 to 1.0554e-03.
# Adjusting learning rate of group 0 to 1.0561e-03.
# Adjusting learning rate of group 0 to 1.0569e-03.
# Adjusting learning rate of group 0 to 1.0577e-03.
# Adjusting learning rate of group 0 to 1.0585e-03.
# Adjusting learning rate of group 0 to 1.0593e-03.
# Adjusting learning rate of group 0 to 1.0601e-03.
# train [0,   150] loss: 0.676
# train [0,   150] acc: 0.762
# Adjusting learning rate of group 0 to 1.0609e-03.
# Adjusting learning rate of group 0 to 1.0617e-03.
# Adjusting learning rate of group 0 to 1.0625e-03.
# Adjusting learning rate of group 0 to 1.0633e-03.
# Adjusting learning rate of group 0 to 1.0641e-03.
# Adjusting learning rate of group 0 to 1.0650e-03.
# Adjusting learning rate of group 0 to 1.0658e-03.
# Adjusting learning rate of group 0 to 1.0666e-03.
# Adjusting learning rate of group 0 to 1.0675e-03.
# Adjusting learning rate of group 0 to 1.0683e-03.
# train [0,   160] loss: 0.583
# train [0,   160] acc: 0.850
# Adjusting learning rate of group 0 to 1.0692e-03.
# Adjusting learning rate of group 0 to 1.0701e-03.
# Adjusting learning rate of group 0 to 1.0709e-03.
# Adjusting learning rate of group 0 to 1.0718e-03.
# Adjusting learning rate of group 0 to 1.0727e-03.
# Adjusting learning rate of group 0 to 1.0736e-03.
# Adjusting learning rate of group 0 to 1.0745e-03.
# Adjusting learning rate of group 0 to 1.0753e-03.
# Adjusting learning rate of group 0 to 1.0762e-03.
# Adjusting learning rate of group 0 to 1.0771e-03.
# train [0,   170] loss: 0.526
# train [0,   170] acc: 0.825
# Adjusting learning rate of group 0 to 1.0781e-03.
# Adjusting learning rate of group 0 to 1.0790e-03.
# Adjusting learning rate of group 0 to 1.0799e-03.
# Adjusting learning rate of group 0 to 1.0808e-03.
# Adjusting learning rate of group 0 to 1.0818e-03.
# Adjusting learning rate of group 0 to 1.0827e-03.
# Adjusting learning rate of group 0 to 1.0836e-03.
# Adjusting learning rate of group 0 to 1.0846e-03.
# Adjusting learning rate of group 0 to 1.0855e-03.
# Adjusting learning rate of group 0 to 1.0865e-03.
# train [0,   180] loss: 0.516
# train [0,   180] acc: 0.850
# Adjusting learning rate of group 0 to 1.0875e-03.
# Adjusting learning rate of group 0 to 1.0884e-03.
# Adjusting learning rate of group 0 to 1.0894e-03.
# Adjusting learning rate of group 0 to 1.0904e-03.
# Adjusting learning rate of group 0 to 1.0914e-03.
# Adjusting learning rate of group 0 to 1.0923e-03.
# Adjusting learning rate of group 0 to 1.0933e-03.
# Adjusting learning rate of group 0 to 1.0943e-03.
# Adjusting learning rate of group 0 to 1.0953e-03.
# Adjusting learning rate of group 0 to 1.0964e-03.
# train [0,   190] loss: 0.532
# train [0,   190] acc: 0.788
# Adjusting learning rate of group 0 to 1.0974e-03.
# Adjusting learning rate of group 0 to 1.0984e-03.
# Adjusting learning rate of group 0 to 1.0994e-03.
# Adjusting learning rate of group 0 to 1.1005e-03.
# Adjusting learning rate of group 0 to 1.1015e-03.
# Adjusting learning rate of group 0 to 1.1025e-03.
# Adjusting learning rate of group 0 to 1.1036e-03.
# Adjusting learning rate of group 0 to 1.1046e-03.
# Adjusting learning rate of group 0 to 1.1057e-03.
# Adjusting learning rate of group 0 to 1.1068e-03.
# train [0,   200] loss: 0.480
# train [0,   200] acc: 0.812
# Adjusting learning rate of group 0 to 1.1078e-03.
# Adjusting learning rate of group 0 to 1.1089e-03.
# Adjusting learning rate of group 0 to 1.1100e-03.
# Adjusting learning rate of group 0 to 1.1111e-03.
# Adjusting learning rate of group 0 to 1.1122e-03.
# Adjusting learning rate of group 0 to 1.1133e-03.
# Adjusting learning rate of group 0 to 1.1144e-03.
# Adjusting learning rate of group 0 to 1.1155e-03.
# Adjusting learning rate of group 0 to 1.1166e-03.
# Adjusting learning rate of group 0 to 1.1177e-03.
# train [0,   210] loss: 0.660
# train [0,   210] acc: 0.800
# Adjusting learning rate of group 0 to 1.1188e-03.
# Adjusting learning rate of group 0 to 1.1199e-03.
# Adjusting learning rate of group 0 to 1.1211e-03.
# Adjusting learning rate of group 0 to 1.1222e-03.
# Adjusting learning rate of group 0 to 1.1234e-03.
# Adjusting learning rate of group 0 to 1.1245e-03.
# Adjusting learning rate of group 0 to 1.1257e-03.
# Adjusting learning rate of group 0 to 1.1268e-03.
# Adjusting learning rate of group 0 to 1.1280e-03.
# Adjusting learning rate of group 0 to 1.1292e-03.
# train [0,   220] loss: 0.479
# train [0,   220] acc: 0.825
# Adjusting learning rate of group 0 to 1.1303e-03.
# Adjusting learning rate of group 0 to 1.1315e-03.
# Adjusting learning rate of group 0 to 1.1327e-03.
# Adjusting learning rate of group 0 to 1.1339e-03.
# Adjusting learning rate of group 0 to 1.1351e-03.
# Adjusting learning rate of group 0 to 1.1363e-03.
# Adjusting learning rate of group 0 to 1.1375e-03.
# Adjusting learning rate of group 0 to 1.1387e-03.
# Adjusting learning rate of group 0 to 1.1399e-03.
# Adjusting learning rate of group 0 to 1.1412e-03.
# train [0,   230] loss: 0.426
# train [0,   230] acc: 0.875
# Adjusting learning rate of group 0 to 1.1424e-03.
# Adjusting learning rate of group 0 to 1.1436e-03.
# Adjusting learning rate of group 0 to 1.1449e-03.
# Adjusting learning rate of group 0 to 1.1461e-03.
# Adjusting learning rate of group 0 to 1.1474e-03.
# Adjusting learning rate of group 0 to 1.1486e-03.
# Adjusting learning rate of group 0 to 1.1499e-03.
# Adjusting learning rate of group 0 to 1.1511e-03.
# Adjusting learning rate of group 0 to 1.1524e-03.
# Adjusting learning rate of group 0 to 1.1537e-03.
# train [0,   240] loss: 0.386
# train [0,   240] acc: 0.887
# Adjusting learning rate of group 0 to 1.1550e-03.
# Adjusting learning rate of group 0 to 1.1563e-03.
# Adjusting learning rate of group 0 to 1.1575e-03.
# Adjusting learning rate of group 0 to 1.1588e-03.
# Adjusting learning rate of group 0 to 1.1601e-03.
# Adjusting learning rate of group 0 to 1.1615e-03.
# Adjusting learning rate of group 0 to 1.1628e-03.
# Adjusting learning rate of group 0 to 1.1641e-03.
# Adjusting learning rate of group 0 to 1.1654e-03.
# Adjusting learning rate of group 0 to 1.1667e-03.
# train [0,   250] loss: 0.541
# train [0,   250] acc: 0.825
# Adjusting learning rate of group 0 to 1.1681e-03.
# Adjusting learning rate of group 0 to 1.1694e-03.
# Adjusting learning rate of group 0 to 1.1708e-03.
# Adjusting learning rate of group 0 to 1.1721e-03.
# Adjusting learning rate of group 0 to 1.1735e-03.
# Adjusting learning rate of group 0 to 1.1748e-03.
# Adjusting learning rate of group 0 to 1.1762e-03.
# Adjusting learning rate of group 0 to 1.1776e-03.
# Adjusting learning rate of group 0 to 1.1790e-03.
# Adjusting learning rate of group 0 to 1.1803e-03.
# train [0,   260] loss: 0.314
# train [0,   260] acc: 0.925
# Adjusting learning rate of group 0 to 1.1817e-03.
# Adjusting learning rate of group 0 to 1.1831e-03.
# Adjusting learning rate of group 0 to 1.1845e-03.
# Adjusting learning rate of group 0 to 1.1859e-03.
# Adjusting learning rate of group 0 to 1.1873e-03.
# Adjusting learning rate of group 0 to 1.1887e-03.
# Adjusting learning rate of group 0 to 1.1902e-03.
# Adjusting learning rate of group 0 to 1.1916e-03.
# Adjusting learning rate of group 0 to 1.1930e-03.
# Adjusting learning rate of group 0 to 1.1945e-03.
# train [0,   270] loss: 0.422
# train [0,   270] acc: 0.863
# Adjusting learning rate of group 0 to 1.1959e-03.
# Adjusting learning rate of group 0 to 1.1973e-03.
# Adjusting learning rate of group 0 to 1.1988e-03.
# Adjusting learning rate of group 0 to 1.2002e-03.
# Adjusting learning rate of group 0 to 1.2017e-03.
# Adjusting learning rate of group 0 to 1.2032e-03.
# Adjusting learning rate of group 0 to 1.2047e-03.
# Adjusting learning rate of group 0 to 1.2061e-03.
# Adjusting learning rate of group 0 to 1.2076e-03.
# Adjusting learning rate of group 0 to 1.2091e-03.
# train [0,   280] loss: 0.232
# train [0,   280] acc: 0.950
# Adjusting learning rate of group 0 to 1.2106e-03.
# Adjusting learning rate of group 0 to 1.2121e-03.
# Adjusting learning rate of group 0 to 1.2136e-03.
# Adjusting learning rate of group 0 to 1.2151e-03.
# Adjusting learning rate of group 0 to 1.2166e-03.
# Adjusting learning rate of group 0 to 1.2181e-03.
# Adjusting learning rate of group 0 to 1.2197e-03.
# Adjusting learning rate of group 0 to 1.2212e-03.
# Adjusting learning rate of group 0 to 1.2227e-03.
# Adjusting learning rate of group 0 to 1.2243e-03.
# train [0,   290] loss: 0.435
# train [0,   290] acc: 0.838
# Adjusting learning rate of group 0 to 1.2258e-03.
# Adjusting learning rate of group 0 to 1.2274e-03.
# Adjusting learning rate of group 0 to 1.2289e-03.
# Adjusting learning rate of group 0 to 1.2305e-03.
# Adjusting learning rate of group 0 to 1.2321e-03.
# Adjusting learning rate of group 0 to 1.2336e-03.
# Adjusting learning rate of group 0 to 1.2352e-03.
# Adjusting learning rate of group 0 to 1.2368e-03.
# Adjusting learning rate of group 0 to 1.2384e-03.
# Adjusting learning rate of group 0 to 1.2400e-03.
# train [0,   300] loss: 0.307
# train [0,   300] acc: 0.925
# Adjusting learning rate of group 0 to 1.2416e-03.
# Adjusting learning rate of group 0 to 1.2432e-03.
# Adjusting learning rate of group 0 to 1.2448e-03.
# Adjusting learning rate of group 0 to 1.2464e-03.
# Adjusting learning rate of group 0 to 1.2480e-03.
# Adjusting learning rate of group 0 to 1.2497e-03.
# Adjusting learning rate of group 0 to 1.2513e-03.
# Adjusting learning rate of group 0 to 1.2529e-03.
# Adjusting learning rate of group 0 to 1.2546e-03.
# Adjusting learning rate of group 0 to 1.2562e-03.
# train [0,   310] loss: 0.296
# train [0,   310] acc: 0.925
# Adjusting learning rate of group 0 to 1.2579e-03.
# Adjusting learning rate of group 0 to 1.2595e-03.
# Adjusting learning rate of group 0 to 1.2612e-03.
# Adjusting learning rate of group 0 to 1.2629e-03.
# Adjusting learning rate of group 0 to 1.2645e-03.
# Adjusting learning rate of group 0 to 1.2662e-03.
# Adjusting learning rate of group 0 to 1.2679e-03.
# Adjusting learning rate of group 0 to 1.2696e-03.
# Adjusting learning rate of group 0 to 1.2713e-03.
# Adjusting learning rate of group 0 to 1.2730e-03.
# train [0,   320] loss: 0.327
# train [0,   320] acc: 0.925
# Adjusting learning rate of group 0 to 1.2747e-03.
# Adjusting learning rate of group 0 to 1.2764e-03.
# Adjusting learning rate of group 0 to 1.2781e-03.
# Adjusting learning rate of group 0 to 1.2799e-03.
# Adjusting learning rate of group 0 to 1.2816e-03.
# Adjusting learning rate of group 0 to 1.2833e-03.
# Adjusting learning rate of group 0 to 1.2850e-03.
# Adjusting learning rate of group 0 to 1.2868e-03.
# Adjusting learning rate of group 0 to 1.2885e-03.
# Adjusting learning rate of group 0 to 1.2903e-03.
# train [0,   330] loss: 0.504
# train [0,   330] acc: 0.850
# Adjusting learning rate of group 0 to 1.2920e-03.
# Adjusting learning rate of group 0 to 1.2938e-03.
# Adjusting learning rate of group 0 to 1.2956e-03.
# Adjusting learning rate of group 0 to 1.2974e-03.
# Adjusting learning rate of group 0 to 1.2991e-03.
# Adjusting learning rate of group 0 to 1.3009e-03.
# Adjusting learning rate of group 0 to 1.3027e-03.
# Adjusting learning rate of group 0 to 1.3045e-03.
# Adjusting learning rate of group 0 to 1.3063e-03.
# Adjusting learning rate of group 0 to 1.3081e-03.
# train [0,   340] loss: 0.423
# train [0,   340] acc: 0.875
# Adjusting learning rate of group 0 to 1.3099e-03.
# Adjusting learning rate of group 0 to 1.3117e-03.
# Adjusting learning rate of group 0 to 1.3136e-03.
# Adjusting learning rate of group 0 to 1.3154e-03.
# Adjusting learning rate of group 0 to 1.3172e-03.
# Adjusting learning rate of group 0 to 1.3191e-03.
# Adjusting learning rate of group 0 to 1.3209e-03.
# Adjusting learning rate of group 0 to 1.3228e-03.
# Adjusting learning rate of group 0 to 1.3246e-03.
# Adjusting learning rate of group 0 to 1.3265e-03.
# train [0,   350] loss: 0.309
# train [0,   350] acc: 0.887
# Adjusting learning rate of group 0 to 1.3283e-03.
# Adjusting learning rate of group 0 to 1.3302e-03.
# Adjusting learning rate of group 0 to 1.3321e-03.
# Adjusting learning rate of group 0 to 1.3339e-03.
# Adjusting learning rate of group 0 to 1.3358e-03.
# Adjusting learning rate of group 0 to 1.3377e-03.
# Adjusting learning rate of group 0 to 1.3396e-03.
# Adjusting learning rate of group 0 to 1.3415e-03.
# Adjusting learning rate of group 0 to 1.3434e-03.
# Adjusting learning rate of group 0 to 1.3453e-03.
# train [0,   360] loss: 0.352
# train [0,   360] acc: 0.913
# Adjusting learning rate of group 0 to 1.3473e-03.
# Adjusting learning rate of group 0 to 1.3492e-03.
# Adjusting learning rate of group 0 to 1.3511e-03.
# Adjusting learning rate of group 0 to 1.3530e-03.
# Adjusting learning rate of group 0 to 1.3550e-03.
# Adjusting learning rate of group 0 to 1.3569e-03.
# Adjusting learning rate of group 0 to 1.3589e-03.
# Adjusting learning rate of group 0 to 1.3608e-03.
# Adjusting learning rate of group 0 to 1.3628e-03.
# Adjusting learning rate of group 0 to 1.3647e-03.
# train [0,   370] loss: 0.353
# train [0,   370] acc: 0.913
# Adjusting learning rate of group 0 to 1.3667e-03.
# Adjusting learning rate of group 0 to 1.3687e-03.
# Adjusting learning rate of group 0 to 1.3707e-03.
# Adjusting learning rate of group 0 to 1.3727e-03.
# Adjusting learning rate of group 0 to 1.3746e-03.
# Adjusting learning rate of group 0 to 1.3766e-03.
# Adjusting learning rate of group 0 to 1.3786e-03.
# Adjusting learning rate of group 0 to 1.3806e-03.
# Adjusting learning rate of group 0 to 1.3827e-03.
# Adjusting learning rate of group 0 to 1.3847e-03.
# train [0,   380] loss: 0.435
# train [0,   380] acc: 0.850
# Adjusting learning rate of group 0 to 1.3867e-03.
# Adjusting learning rate of group 0 to 1.3887e-03.
# Adjusting learning rate of group 0 to 1.3908e-03.
# Adjusting learning rate of group 0 to 1.3928e-03.
# Adjusting learning rate of group 0 to 1.3948e-03.
# Adjusting learning rate of group 0 to 1.3969e-03.
# Adjusting learning rate of group 0 to 1.3989e-03.
# Adjusting learning rate of group 0 to 1.4010e-03.
# Adjusting learning rate of group 0 to 1.4031e-03.
# Adjusting learning rate of group 0 to 1.4051e-03.
# train [0,   390] loss: 0.450
# train [0,   390] acc: 0.825
# Adjusting learning rate of group 0 to 1.4072e-03.
# Adjusting learning rate of group 0 to 1.4093e-03.
# Adjusting learning rate of group 0 to 1.4114e-03.
# Adjusting learning rate of group 0 to 1.4135e-03.
# Adjusting learning rate of group 0 to 1.4156e-03.
# Adjusting learning rate of group 0 to 1.4177e-03.
# Adjusting learning rate of group 0 to 1.4198e-03.
# Adjusting learning rate of group 0 to 1.4219e-03.
# Adjusting learning rate of group 0 to 1.4240e-03.
# Adjusting learning rate of group 0 to 1.4261e-03.
# train [0,   400] loss: 0.393
# train [0,   400] acc: 0.925
# Adjusting learning rate of group 0 to 1.4282e-03.
# Adjusting learning rate of group 0 to 1.4304e-03.
# Adjusting learning rate of group 0 to 1.4325e-03.
# Adjusting learning rate of group 0 to 1.4346e-03.
# Adjusting learning rate of group 0 to 1.4368e-03.
# Adjusting learning rate of group 0 to 1.4389e-03.
# Adjusting learning rate of group 0 to 1.4411e-03.
# Adjusting learning rate of group 0 to 1.4433e-03.
# Adjusting learning rate of group 0 to 1.4454e-03.
# Adjusting learning rate of group 0 to 1.4476e-03.
# train [0,   410] loss: 0.370
# train [0,   410] acc: 0.863
# Adjusting learning rate of group 0 to 1.4498e-03.
# Adjusting learning rate of group 0 to 1.4520e-03.
# Adjusting learning rate of group 0 to 1.4542e-03.
# Adjusting learning rate of group 0 to 1.4564e-03.
# Adjusting learning rate of group 0 to 1.4586e-03.
# Adjusting learning rate of group 0 to 1.4608e-03.
# Adjusting learning rate of group 0 to 1.4630e-03.
# Adjusting learning rate of group 0 to 1.4652e-03.
# Adjusting learning rate of group 0 to 1.4674e-03.
# Adjusting learning rate of group 0 to 1.4696e-03.
# train [0,   420] loss: 0.257
# train [0,   420] acc: 0.925
# Adjusting learning rate of group 0 to 1.4719e-03.
# Adjusting learning rate of group 0 to 1.4741e-03.
# Adjusting learning rate of group 0 to 1.4764e-03.
# Adjusting learning rate of group 0 to 1.4786e-03.
# Adjusting learning rate of group 0 to 1.4809e-03.
# Adjusting learning rate of group 0 to 1.4831e-03.
# Adjusting learning rate of group 0 to 1.4854e-03.
# Adjusting learning rate of group 0 to 1.4876e-03.
# Adjusting learning rate of group 0 to 1.4899e-03.
# Adjusting learning rate of group 0 to 1.4922e-03.
# train [0,   430] loss: 0.380
# train [0,   430] acc: 0.900
# Adjusting learning rate of group 0 to 1.4945e-03.
# Adjusting learning rate of group 0 to 1.4968e-03.
# Adjusting learning rate of group 0 to 1.4991e-03.
# Adjusting learning rate of group 0 to 1.5014e-03.
# Adjusting learning rate of group 0 to 1.5037e-03.
# Adjusting learning rate of group 0 to 1.5060e-03.
# Adjusting learning rate of group 0 to 1.5083e-03.
# Adjusting learning rate of group 0 to 1.5106e-03.
# Adjusting learning rate of group 0 to 1.5129e-03.
# Adjusting learning rate of group 0 to 1.5153e-03.
# train [0,   440] loss: 0.306
# train [0,   440] acc: 0.900
# Adjusting learning rate of group 0 to 1.5176e-03.
# Adjusting learning rate of group 0 to 1.5200e-03.
# Adjusting learning rate of group 0 to 1.5223e-03.
# Adjusting learning rate of group 0 to 1.5247e-03.
# Adjusting learning rate of group 0 to 1.5270e-03.
# Adjusting learning rate of group 0 to 1.5294e-03.
# Adjusting learning rate of group 0 to 1.5317e-03.
# Adjusting learning rate of group 0 to 1.5341e-03.
# Adjusting learning rate of group 0 to 1.5365e-03.
# Adjusting learning rate of group 0 to 1.5389e-03.
# train [0,   450] loss: 0.122
# train [0,   450] acc: 0.950
# Adjusting learning rate of group 0 to 1.5413e-03.
# Adjusting learning rate of group 0 to 1.5437e-03.
# Adjusting learning rate of group 0 to 1.5461e-03.
# Adjusting learning rate of group 0 to 1.5485e-03.
# Adjusting learning rate of group 0 to 1.5509e-03.
# Adjusting learning rate of group 0 to 1.5533e-03.
# Adjusting learning rate of group 0 to 1.5557e-03.
# Adjusting learning rate of group 0 to 1.5581e-03.
# Adjusting learning rate of group 0 to 1.5606e-03.
# Adjusting learning rate of group 0 to 1.5630e-03.
# train [0,   460] loss: 0.212
# train [0,   460] acc: 0.950
# Adjusting learning rate of group 0 to 1.5654e-03.
# Adjusting learning rate of group 0 to 1.5679e-03.
# Adjusting learning rate of group 0 to 1.5703e-03.
# Adjusting learning rate of group 0 to 1.5728e-03.
# Adjusting learning rate of group 0 to 1.5753e-03.
# Adjusting learning rate of group 0 to 1.5777e-03.
# Adjusting learning rate of group 0 to 1.5802e-03.
# Adjusting learning rate of group 0 to 1.5827e-03.
# Adjusting learning rate of group 0 to 1.5852e-03.
# Adjusting learning rate of group 0 to 1.5876e-03.
# train [0,   470] loss: 0.573
# train [0,   470] acc: 0.850
# Adjusting learning rate of group 0 to 1.5901e-03.
# Adjusting learning rate of group 0 to 1.5926e-03.
# Adjusting learning rate of group 0 to 1.5951e-03.
# Adjusting learning rate of group 0 to 1.5976e-03.
# Adjusting learning rate of group 0 to 1.6002e-03.
# Adjusting learning rate of group 0 to 1.6027e-03.
# Adjusting learning rate of group 0 to 1.6052e-03.
# Adjusting learning rate of group 0 to 1.6077e-03.
# Adjusting learning rate of group 0 to 1.6103e-03.
# Adjusting learning rate of group 0 to 1.6128e-03.
# train [0,   480] loss: 0.565
# train [0,   480] acc: 0.838
# Adjusting learning rate of group 0 to 1.6154e-03.
# Adjusting learning rate of group 0 to 1.6179e-03.
# Adjusting learning rate of group 0 to 1.6205e-03.
# Adjusting learning rate of group 0 to 1.6230e-03.
# Adjusting learning rate of group 0 to 1.6256e-03.
# Adjusting learning rate of group 0 to 1.6282e-03.
# Adjusting learning rate of group 0 to 1.6307e-03.
# Adjusting learning rate of group 0 to 1.6333e-03.
# Adjusting learning rate of group 0 to 1.6359e-03.
# Adjusting learning rate of group 0 to 1.6385e-03.
# train [0,   490] loss: 0.369
# train [0,   490] acc: 0.875
# Adjusting learning rate of group 0 to 1.6411e-03.
# Adjusting learning rate of group 0 to 1.6437e-03.
# Adjusting learning rate of group 0 to 1.6463e-03.
# Adjusting learning rate of group 0 to 1.6489e-03.
# Adjusting learning rate of group 0 to 1.6515e-03.
# Adjusting learning rate of group 0 to 1.6542e-03.
# Adjusting learning rate of group 0 to 1.6568e-03.
# Adjusting learning rate of group 0 to 1.6594e-03.
# Adjusting learning rate of group 0 to 1.6621e-03.
# Adjusting learning rate of group 0 to 1.6647e-03.
# train [0,   500] loss: 0.270
# train [0,   500] acc: 0.900
# Adjusting learning rate of group 0 to 1.6674e-03.
# Adjusting learning rate of group 0 to 1.6700e-03.
# Adjusting learning rate of group 0 to 1.6727e-03.
# Adjusting learning rate of group 0 to 1.6753e-03.
# Adjusting learning rate of group 0 to 1.6780e-03.
# Adjusting learning rate of group 0 to 1.6807e-03.
# Adjusting learning rate of group 0 to 1.6834e-03.
# Adjusting learning rate of group 0 to 1.6860e-03.
# Adjusting learning rate of group 0 to 1.6887e-03.
# Adjusting learning rate of group 0 to 1.6914e-03.
# train [0,   510] loss: 0.145
# train [0,   510] acc: 0.950
# Adjusting learning rate of group 0 to 1.6941e-03.
# Adjusting learning rate of group 0 to 1.6968e-03.
# Adjusting learning rate of group 0 to 1.6996e-03.
# Adjusting learning rate of group 0 to 1.7023e-03.
# Adjusting learning rate of group 0 to 1.7050e-03.
# Adjusting learning rate of group 0 to 1.7077e-03.
# Adjusting learning rate of group 0 to 1.7105e-03.
# Adjusting learning rate of group 0 to 1.7132e-03.
# Adjusting learning rate of group 0 to 1.7159e-03.
# Adjusting learning rate of group 0 to 1.7187e-03.
# train [0,   520] loss: 0.233
# train [0,   520] acc: 0.925
# Adjusting learning rate of group 0 to 1.7214e-03.
# Adjusting learning rate of group 0 to 1.7242e-03.
# Adjusting learning rate of group 0 to 1.7270e-03.
# Adjusting learning rate of group 0 to 1.7297e-03.
# Adjusting learning rate of group 0 to 1.7325e-03.
# Adjusting learning rate of group 0 to 1.7353e-03.
# Adjusting learning rate of group 0 to 1.7381e-03.
# Adjusting learning rate of group 0 to 1.7409e-03.
# Adjusting learning rate of group 0 to 1.7436e-03.
# Adjusting learning rate of group 0 to 1.7464e-03.
# train [0,   530] loss: 0.554
# train [0,   530] acc: 0.850
# Adjusting learning rate of group 0 to 1.7493e-03.
# Adjusting learning rate of group 0 to 1.7521e-03.
# Adjusting learning rate of group 0 to 1.7549e-03.
# Adjusting learning rate of group 0 to 1.7577e-03.
# Adjusting learning rate of group 0 to 1.7605e-03.
# Adjusting learning rate of group 0 to 1.7634e-03.
# Adjusting learning rate of group 0 to 1.7662e-03.
# Adjusting learning rate of group 0 to 1.7690e-03.
# Adjusting learning rate of group 0 to 1.7719e-03.
# Adjusting learning rate of group 0 to 1.7747e-03.
# train [0,   540] loss: 0.305
# train [0,   540] acc: 0.900
# Adjusting learning rate of group 0 to 1.7776e-03.
# Adjusting learning rate of group 0 to 1.7804e-03.
# Adjusting learning rate of group 0 to 1.7833e-03.
# Adjusting learning rate of group 0 to 1.7862e-03.
# Adjusting learning rate of group 0 to 1.7891e-03.
# Adjusting learning rate of group 0 to 1.7919e-03.
# Adjusting learning rate of group 0 to 1.7948e-03.
# Adjusting learning rate of group 0 to 1.7977e-03.
# Adjusting learning rate of group 0 to 1.8006e-03.
# Adjusting learning rate of group 0 to 1.8035e-03.
# train [0,   550] loss: 0.273
# train [0,   550] acc: 0.900
# Adjusting learning rate of group 0 to 1.8064e-03.
# Adjusting learning rate of group 0 to 1.8093e-03.
# Adjusting learning rate of group 0 to 1.8123e-03.
# Adjusting learning rate of group 0 to 1.8152e-03.
# Adjusting learning rate of group 0 to 1.8181e-03.
# Adjusting learning rate of group 0 to 1.8211e-03.
# Adjusting learning rate of group 0 to 1.8240e-03.
# Adjusting learning rate of group 0 to 1.8269e-03.
# Adjusting learning rate of group 0 to 1.8299e-03.
# Adjusting learning rate of group 0 to 1.8328e-03.
# train [0,   560] loss: 0.166
# train [0,   560] acc: 0.938
# Adjusting learning rate of group 0 to 1.8358e-03.
# Adjusting learning rate of group 0 to 1.8388e-03.
# Adjusting learning rate of group 0 to 1.8417e-03.
# Adjusting learning rate of group 0 to 1.8447e-03.
# Adjusting learning rate of group 0 to 1.8477e-03.
# Adjusting learning rate of group 0 to 1.8507e-03.
# Adjusting learning rate of group 0 to 1.8537e-03.
# Adjusting learning rate of group 0 to 1.8567e-03.
# Adjusting learning rate of group 0 to 1.8597e-03.
# Adjusting learning rate of group 0 to 1.8627e-03.
# train [0,   570] loss: 0.517
# train [0,   570] acc: 0.863
# Adjusting learning rate of group 0 to 1.8657e-03.
# Adjusting learning rate of group 0 to 1.8687e-03.
# Adjusting learning rate of group 0 to 1.8717e-03.
# Adjusting learning rate of group 0 to 1.8748e-03.
# Adjusting learning rate of group 0 to 1.8778e-03.
# Adjusting learning rate of group 0 to 1.8808e-03.
# Adjusting learning rate of group 0 to 1.8839e-03.
# Adjusting learning rate of group 0 to 1.8869e-03.
# Adjusting learning rate of group 0 to 1.8900e-03.
# Adjusting learning rate of group 0 to 1.8930e-03.
# train [0,   580] loss: 0.596
# train [0,   580] acc: 0.775
# Adjusting learning rate of group 0 to 1.8961e-03.
# Adjusting learning rate of group 0 to 1.8992e-03.
# Adjusting learning rate of group 0 to 1.9022e-03.
# Adjusting learning rate of group 0 to 1.9053e-03.
# Adjusting learning rate of group 0 to 1.9084e-03.
# Adjusting learning rate of group 0 to 1.9115e-03.
# Adjusting learning rate of group 0 to 1.9146e-03.
# Adjusting learning rate of group 0 to 1.9177e-03.
# Adjusting learning rate of group 0 to 1.9208e-03.
# Adjusting learning rate of group 0 to 1.9239e-03.
# train [0,   590] loss: 0.481
# train [0,   590] acc: 0.875
# Adjusting learning rate of group 0 to 1.9270e-03.
# Adjusting learning rate of group 0 to 1.9301e-03.
# Adjusting learning rate of group 0 to 1.9332e-03.
# Adjusting learning rate of group 0 to 1.9364e-03.
# Adjusting learning rate of group 0 to 1.9395e-03.
# Adjusting learning rate of group 0 to 1.9427e-03.
# Adjusting learning rate of group 0 to 1.9458e-03.
# Adjusting learning rate of group 0 to 1.9489e-03.
# Adjusting learning rate of group 0 to 1.9521e-03.
# Adjusting learning rate of group 0 to 1.9553e-03.
# train [0,   600] loss: 0.423
# train [0,   600] acc: 0.850
# Adjusting learning rate of group 0 to 1.9584e-03.
# Adjusting learning rate of group 0 to 1.9616e-03.
# Adjusting learning rate of group 0 to 1.9648e-03.
# Adjusting learning rate of group 0 to 1.9680e-03.
# Adjusting learning rate of group 0 to 1.9711e-03.
# Adjusting learning rate of group 0 to 1.9743e-03.
# Adjusting learning rate of group 0 to 1.9775e-03.
# Adjusting learning rate of group 0 to 1.9807e-03.
# Adjusting learning rate of group 0 to 1.9839e-03.
# Adjusting learning rate of group 0 to 1.9872e-03.
# train [0,   610] loss: 0.459
# train [0,   610] acc: 0.887
# Adjusting learning rate of group 0 to 1.9904e-03.
# Adjusting learning rate of group 0 to 1.9936e-03.
# Adjusting learning rate of group 0 to 1.9968e-03.
# Adjusting learning rate of group 0 to 2.0001e-03.
# Adjusting learning rate of group 0 to 2.0033e-03.
# Adjusting learning rate of group 0 to 2.0065e-03.
# Adjusting learning rate of group 0 to 2.0098e-03.
# Adjusting learning rate of group 0 to 2.0130e-03.
# Adjusting learning rate of group 0 to 2.0163e-03.
# Adjusting learning rate of group 0 to 2.0196e-03.
# train [0,   620] loss: 0.486
# train [0,   620] acc: 0.875
# Adjusting learning rate of group 0 to 2.0228e-03.
# Adjusting learning rate of group 0 to 2.0261e-03.
# Adjusting learning rate of group 0 to 2.0294e-03.
# Adjusting learning rate of group 0 to 2.0327e-03.
# Adjusting learning rate of group 0 to 2.0360e-03.
# Adjusting learning rate of group 0 to 2.0392e-03.
# Adjusting learning rate of group 0 to 2.0425e-03.
# Adjusting learning rate of group 0 to 2.0458e-03.
# Adjusting learning rate of group 0 to 2.0492e-03.
# Adjusting learning rate of group 0 to 2.0525e-03.
# train [0,   630] loss: 0.682
# train [0,   630] acc: 0.838
# Adjusting learning rate of group 0 to 2.0558e-03.
# Adjusting learning rate of group 0 to 2.0591e-03.
# Adjusting learning rate of group 0 to 2.0624e-03.
# Adjusting learning rate of group 0 to 2.0658e-03.
# Adjusting learning rate of group 0 to 2.0691e-03.
# Adjusting learning rate of group 0 to 2.0725e-03.
# Adjusting learning rate of group 0 to 2.0758e-03.
# Adjusting learning rate of group 0 to 2.0792e-03.
# Adjusting learning rate of group 0 to 2.0825e-03.
# Adjusting learning rate of group 0 to 2.0859e-03.
# train [0,   640] loss: 0.489
# train [0,   640] acc: 0.825
# Adjusting learning rate of group 0 to 2.0893e-03.
# Adjusting learning rate of group 0 to 2.0926e-03.
# Adjusting learning rate of group 0 to 2.0960e-03.
# Adjusting learning rate of group 0 to 2.0994e-03.
# Adjusting learning rate of group 0 to 2.1028e-03.
# Adjusting learning rate of group 0 to 2.1062e-03.
# Adjusting learning rate of group 0 to 2.1096e-03.
# Adjusting learning rate of group 0 to 2.1130e-03.
# Adjusting learning rate of group 0 to 2.1164e-03.
# Adjusting learning rate of group 0 to 2.1198e-03.
# train [0,   650] loss: 0.417
# train [0,   650] acc: 0.875
# Adjusting learning rate of group 0 to 2.1233e-03.
# Adjusting learning rate of group 0 to 2.1267e-03.
# Adjusting learning rate of group 0 to 2.1301e-03.
# Adjusting learning rate of group 0 to 2.1336e-03.
# Adjusting learning rate of group 0 to 2.1370e-03.
# Adjusting learning rate of group 0 to 2.1404e-03.
# Adjusting learning rate of group 0 to 2.1439e-03.
# Adjusting learning rate of group 0 to 2.1474e-03.
# Adjusting learning rate of group 0 to 2.1508e-03.
# Adjusting learning rate of group 0 to 2.1543e-03.
# train [0,   660] loss: 0.823
# train [0,   660] acc: 0.750
# Adjusting learning rate of group 0 to 2.1578e-03.
# Adjusting learning rate of group 0 to 2.1612e-03.
# Adjusting learning rate of group 0 to 2.1647e-03.
# Adjusting learning rate of group 0 to 2.1682e-03.
# Adjusting learning rate of group 0 to 2.1717e-03.
# Adjusting learning rate of group 0 to 2.1752e-03.
# Adjusting learning rate of group 0 to 2.1787e-03.
# Adjusting learning rate of group 0 to 2.1822e-03.
# Adjusting learning rate of group 0 to 2.1857e-03.
# Adjusting learning rate of group 0 to 2.1892e-03.
# train [0,   670] loss: 0.490
# train [0,   670] acc: 0.838
# Adjusting learning rate of group 0 to 2.1928e-03.
# Adjusting learning rate of group 0 to 2.1963e-03.
# Adjusting learning rate of group 0 to 2.1998e-03.
# Adjusting learning rate of group 0 to 2.2034e-03.
# Adjusting learning rate of group 0 to 2.2069e-03.
# Adjusting learning rate of group 0 to 2.2105e-03.
# Adjusting learning rate of group 0 to 2.2140e-03.
# Adjusting learning rate of group 0 to 2.2176e-03.
# Adjusting learning rate of group 0 to 2.2211e-03.
# Adjusting learning rate of group 0 to 2.2247e-03.
# train [0,   680] loss: 0.688
# train [0,   680] acc: 0.812
# Adjusting learning rate of group 0 to 2.2283e-03.
# Adjusting learning rate of group 0 to 2.2319e-03.
# Adjusting learning rate of group 0 to 2.2354e-03.
# Adjusting learning rate of group 0 to 2.2390e-03.
# Adjusting learning rate of group 0 to 2.2426e-03.
# Adjusting learning rate of group 0 to 2.2462e-03.
# Adjusting learning rate of group 0 to 2.2498e-03.
# Adjusting learning rate of group 0 to 2.2534e-03.
# Adjusting learning rate of group 0 to 2.2571e-03.
# Adjusting learning rate of group 0 to 2.2607e-03.
# train [0,   690] loss: 0.883
# train [0,   690] acc: 0.825
# Adjusting learning rate of group 0 to 2.2643e-03.
# Adjusting learning rate of group 0 to 2.2679e-03.
# Adjusting learning rate of group 0 to 2.2716e-03.
# Adjusting learning rate of group 0 to 2.2752e-03.
# Adjusting learning rate of group 0 to 2.2788e-03.
# Adjusting learning rate of group 0 to 2.2825e-03.
# Adjusting learning rate of group 0 to 2.2862e-03.
# Adjusting learning rate of group 0 to 2.2898e-03.
# Adjusting learning rate of group 0 to 2.2935e-03.
# Adjusting learning rate of group 0 to 2.2971e-03.
# train [0,   700] loss: 0.685
# train [0,   700] acc: 0.725
# Adjusting learning rate of group 0 to 2.3008e-03.
# Adjusting learning rate of group 0 to 2.3045e-03.
# Adjusting learning rate of group 0 to 2.3082e-03.
# Adjusting learning rate of group 0 to 2.3119e-03.
# Adjusting learning rate of group 0 to 2.3156e-03.
# Adjusting learning rate of group 0 to 2.3193e-03.
# Adjusting learning rate of group 0 to 2.3230e-03.
# Adjusting learning rate of group 0 to 2.3267e-03.
# Adjusting learning rate of group 0 to 2.3304e-03.
# Adjusting learning rate of group 0 to 2.3341e-03.
# train [0,   710] loss: 0.490
# train [0,   710] acc: 0.825
# Adjusting learning rate of group 0 to 2.3379e-03.
# Adjusting learning rate of group 0 to 2.3416e-03.
# Adjusting learning rate of group 0 to 2.3453e-03.
# Adjusting learning rate of group 0 to 2.3491e-03.
# Adjusting learning rate of group 0 to 2.3528e-03.
# Adjusting learning rate of group 0 to 2.3566e-03.
# Adjusting learning rate of group 0 to 2.3603e-03.
# Adjusting learning rate of group 0 to 2.3641e-03.
# Adjusting learning rate of group 0 to 2.3679e-03.
# Adjusting learning rate of group 0 to 2.3716e-03.
# train [0,   720] loss: 0.232
# train [0,   720] acc: 0.913
# Adjusting learning rate of group 0 to 2.3754e-03.
# Adjusting learning rate of group 0 to 2.3792e-03.
# Adjusting learning rate of group 0 to 2.3830e-03.
# Adjusting learning rate of group 0 to 2.3868e-03.
# Adjusting learning rate of group 0 to 2.3906e-03.
# Adjusting learning rate of group 0 to 2.3944e-03.
# Adjusting learning rate of group 0 to 2.3982e-03.
# Adjusting learning rate of group 0 to 2.4020e-03.
# Adjusting learning rate of group 0 to 2.4058e-03.
# Adjusting learning rate of group 0 to 2.4096e-03.
# train [0,   730] loss: 0.473
# train [0,   730] acc: 0.875
# Adjusting learning rate of group 0 to 2.4134e-03.
# Adjusting learning rate of group 0 to 2.4173e-03.
# Adjusting learning rate of group 0 to 2.4211e-03.
# Adjusting learning rate of group 0 to 2.4250e-03.
# Adjusting learning rate of group 0 to 2.4288e-03.
# Adjusting learning rate of group 0 to 2.4327e-03.
# Adjusting learning rate of group 0 to 2.4365e-03.
# Adjusting learning rate of group 0 to 2.4404e-03.
# Adjusting learning rate of group 0 to 2.4442e-03.
# Adjusting learning rate of group 0 to 2.4481e-03.
# train [0,   740] loss: 0.379
# train [0,   740] acc: 0.913
# Adjusting learning rate of group 0 to 2.4520e-03.
# Adjusting learning rate of group 0 to 2.4559e-03.
# Adjusting learning rate of group 0 to 2.4598e-03.
# Adjusting learning rate of group 0 to 2.4637e-03.
# Adjusting learning rate of group 0 to 2.4675e-03.
# Adjusting learning rate of group 0 to 2.4715e-03.
# Adjusting learning rate of group 0 to 2.4754e-03.
# Adjusting learning rate of group 0 to 2.4793e-03.
# Adjusting learning rate of group 0 to 2.4832e-03.
# Adjusting learning rate of group 0 to 2.4871e-03.
# train [0,   750] loss: 0.479
# train [0,   750] acc: 0.838
# Adjusting learning rate of group 0 to 2.4910e-03.
# Adjusting learning rate of group 0 to 2.4950e-03.
# Adjusting learning rate of group 0 to 2.4989e-03.
# Adjusting learning rate of group 0 to 2.5029e-03.
# Adjusting learning rate of group 0 to 2.5068e-03.
# Adjusting learning rate of group 0 to 2.5108e-03.
# Adjusting learning rate of group 0 to 2.5147e-03.
# Adjusting learning rate of group 0 to 2.5187e-03.
# Adjusting learning rate of group 0 to 2.5226e-03.
# Adjusting learning rate of group 0 to 2.5266e-03.
# train [0,   760] loss: 0.189
# train [0,   760] acc: 0.913
# Adjusting learning rate of group 0 to 2.5306e-03.
# Adjusting learning rate of group 0 to 2.5346e-03.
# Adjusting learning rate of group 0 to 2.5386e-03.
# Adjusting learning rate of group 0 to 2.5426e-03.
# Adjusting learning rate of group 0 to 2.5465e-03.
# Adjusting learning rate of group 0 to 2.5506e-03.
# Adjusting learning rate of group 0 to 2.5546e-03.
# Adjusting learning rate of group 0 to 2.5586e-03.
# Adjusting learning rate of group 0 to 2.5626e-03.
# Adjusting learning rate of group 0 to 2.5666e-03.
# train [0,   770] loss: 0.804
# train [0,   770] acc: 0.775
# Adjusting learning rate of group 0 to 2.5706e-03.
# Adjusting learning rate of group 0 to 2.5747e-03.
# Adjusting learning rate of group 0 to 2.5787e-03.
# Adjusting learning rate of group 0 to 2.5828e-03.
# Adjusting learning rate of group 0 to 2.5868e-03.
# Adjusting learning rate of group 0 to 2.5909e-03.
# Adjusting learning rate of group 0 to 2.5949e-03.
# Adjusting learning rate of group 0 to 2.5990e-03.
# Adjusting learning rate of group 0 to 2.6030e-03.
# Adjusting learning rate of group 0 to 2.6071e-03.
# train [0,   780] loss: 0.561
# train [0,   780] acc: 0.850
# Adjusting learning rate of group 0 to 2.6112e-03.
# Adjusting learning rate of group 0 to 2.6153e-03.
# Adjusting learning rate of group 0 to 2.6194e-03.
# Adjusting learning rate of group 0 to 2.6235e-03.
# Adjusting learning rate of group 0 to 2.6276e-03.
# Adjusting learning rate of group 0 to 2.6317e-03.
# Adjusting learning rate of group 0 to 2.6358e-03.
# Adjusting learning rate of group 0 to 2.6399e-03.
# Adjusting learning rate of group 0 to 2.6440e-03.
# Adjusting learning rate of group 0 to 2.6481e-03.
# train [0,   790] loss: 0.750
# train [0,   790] acc: 0.825
# Adjusting learning rate of group 0 to 2.6522e-03.
# Adjusting learning rate of group 0 to 2.6564e-03.
# Adjusting learning rate of group 0 to 2.6605e-03.
# Adjusting learning rate of group 0 to 2.6647e-03.
# Adjusting learning rate of group 0 to 2.6688e-03.
# Adjusting learning rate of group 0 to 2.6730e-03.
# Adjusting learning rate of group 0 to 2.6771e-03.
# Adjusting learning rate of group 0 to 2.6813e-03.
# Adjusting learning rate of group 0 to 2.6854e-03.
# Adjusting learning rate of group 0 to 2.6896e-03.
# train [0,   800] loss: 0.272
# train [0,   800] acc: 0.913
# Adjusting learning rate of group 0 to 2.6938e-03.
# Adjusting learning rate of group 0 to 2.6980e-03.
# Adjusting learning rate of group 0 to 2.7022e-03.
# Adjusting learning rate of group 0 to 2.7064e-03.
# Adjusting learning rate of group 0 to 2.7106e-03.
# Adjusting learning rate of group 0 to 2.7148e-03.
# Adjusting learning rate of group 0 to 2.7190e-03.
# Adjusting learning rate of group 0 to 2.7232e-03.
# Adjusting learning rate of group 0 to 2.7274e-03.
# Adjusting learning rate of group 0 to 2.7316e-03.
# train [0,   810] loss: 0.348
# train [0,   810] acc: 0.887
# Adjusting learning rate of group 0 to 2.7358e-03.
# Adjusting learning rate of group 0 to 2.7401e-03.
# Adjusting learning rate of group 0 to 2.7443e-03.
# Adjusting learning rate of group 0 to 2.7485e-03.
# Adjusting learning rate of group 0 to 2.7528e-03.
# Adjusting learning rate of group 0 to 2.7570e-03.
# Adjusting learning rate of group 0 to 2.7613e-03.
# Adjusting learning rate of group 0 to 2.7656e-03.
# Adjusting learning rate of group 0 to 2.7698e-03.
# Adjusting learning rate of group 0 to 2.7741e-03.
# train [0,   820] loss: 0.427
# train [0,   820] acc: 0.900
# Adjusting learning rate of group 0 to 2.7784e-03.
# Adjusting learning rate of group 0 to 2.7827e-03.
# Adjusting learning rate of group 0 to 2.7869e-03.
# Adjusting learning rate of group 0 to 2.7912e-03.
# Adjusting learning rate of group 0 to 2.7955e-03.
# Adjusting learning rate of group 0 to 2.7998e-03.
# Adjusting learning rate of group 0 to 2.8041e-03.
# Adjusting learning rate of group 0 to 2.8085e-03.
# Adjusting learning rate of group 0 to 2.8128e-03.
# Adjusting learning rate of group 0 to 2.8171e-03.
# train [0,   830] loss: 0.600
# train [0,   830] acc: 0.838
# Adjusting learning rate of group 0 to 2.8214e-03.
# Adjusting learning rate of group 0 to 2.8258e-03.
# Adjusting learning rate of group 0 to 2.8301e-03.
# Adjusting learning rate of group 0 to 2.8344e-03.
# Adjusting learning rate of group 0 to 2.8388e-03.
# Adjusting learning rate of group 0 to 2.8431e-03.
# Adjusting learning rate of group 0 to 2.8475e-03.
# Adjusting learning rate of group 0 to 2.8518e-03.
# Adjusting learning rate of group 0 to 2.8562e-03.
# Adjusting learning rate of group 0 to 2.8606e-03.
# train [0,   840] loss: 0.692
# train [0,   840] acc: 0.825
# Adjusting learning rate of group 0 to 2.8650e-03.
# Adjusting learning rate of group 0 to 2.8693e-03.
# Adjusting learning rate of group 0 to 2.8737e-03.
# Adjusting learning rate of group 0 to 2.8781e-03.
# Adjusting learning rate of group 0 to 2.8825e-03.
# Adjusting learning rate of group 0 to 2.8869e-03.
# Adjusting learning rate of group 0 to 2.8913e-03.
# Adjusting learning rate of group 0 to 2.8957e-03.
# Adjusting learning rate of group 0 to 2.9001e-03.
# Adjusting learning rate of group 0 to 2.9046e-03.
# train [0,   850] loss: 0.632
# train [0,   850] acc: 0.838
# Adjusting learning rate of group 0 to 2.9090e-03.
# Adjusting learning rate of group 0 to 2.9134e-03.
# Adjusting learning rate of group 0 to 2.9178e-03.
# Adjusting learning rate of group 0 to 2.9223e-03.
# Adjusting learning rate of group 0 to 2.9267e-03.
# Adjusting learning rate of group 0 to 2.9312e-03.
# Adjusting learning rate of group 0 to 2.9356e-03.
# Adjusting learning rate of group 0 to 2.9401e-03.
# Adjusting learning rate of group 0 to 2.9446e-03.
# Adjusting learning rate of group 0 to 2.9490e-03.
# train [0,   860] loss: 0.713
# train [0,   860] acc: 0.788
# ...
# Adjusting learning rate of group 0 to 4.0269e-05.
# Adjusting learning rate of group 0 to 3.9987e-05.
# train [9,  1960] loss: 0.004
# train [9,  1960] acc: 1.000
# Adjusting learning rate of group 0 to 3.9705e-05.
# Adjusting learning rate of group 0 to 3.9424e-05.
# Adjusting learning rate of group 0 to 3.9145e-05.
# Adjusting learning rate of group 0 to 3.8866e-05.
# Adjusting learning rate of group 0 to 3.8589e-05.
# Adjusting learning rate of group 0 to 3.8312e-05.
# Adjusting learning rate of group 0 to 3.8036e-05.
# Adjusting learning rate of group 0 to 3.7762e-05.
# Adjusting learning rate of group 0 to 3.7488e-05.
# Adjusting learning rate of group 0 to 3.7216e-05.
# train [9,  1970] loss: 0.005
# train [9,  1970] acc: 1.000
# Adjusting learning rate of group 0 to 3.6944e-05.
# Adjusting learning rate of group 0 to 3.6673e-05.
# Adjusting learning rate of group 0 to 3.6404e-05.
# Adjusting learning rate of group 0 to 3.6135e-05.
# Adjusting learning rate of group 0 to 3.5867e-05.
# Adjusting learning rate of group 0 to 3.5601e-05.
# Adjusting learning rate of group 0 to 3.5335e-05.
# Adjusting learning rate of group 0 to 3.5071e-05.
# Adjusting learning rate of group 0 to 3.4807e-05.
# Adjusting learning rate of group 0 to 3.4544e-05.
# train [9,  1980] loss: 0.003
# train [9,  1980] acc: 1.000
# Adjusting learning rate of group 0 to 3.4283e-05.
# Adjusting learning rate of group 0 to 3.4022e-05.
# Adjusting learning rate of group 0 to 3.3763e-05.
# Adjusting learning rate of group 0 to 3.3504e-05.
# Adjusting learning rate of group 0 to 3.3246e-05.
# Adjusting learning rate of group 0 to 3.2990e-05.
# Adjusting learning rate of group 0 to 3.2734e-05.
# Adjusting learning rate of group 0 to 3.2480e-05.
# Adjusting learning rate of group 0 to 3.2226e-05.
# Adjusting learning rate of group 0 to 3.1973e-05.
# train [9,  1990] loss: 0.004
# train [9,  1990] acc: 1.000
# Adjusting learning rate of group 0 to 3.1722e-05.
# Adjusting learning rate of group 0 to 3.1471e-05.
# Adjusting learning rate of group 0 to 3.1221e-05.
# Adjusting learning rate of group 0 to 3.0973e-05.
# Adjusting learning rate of group 0 to 3.0725e-05.
# Adjusting learning rate of group 0 to 3.0479e-05.
# Adjusting learning rate of group 0 to 3.0233e-05.
# Adjusting learning rate of group 0 to 2.9988e-05.
# Adjusting learning rate of group 0 to 2.9745e-05.
# Adjusting learning rate of group 0 to 2.9502e-05.
# train [9,  2000] loss: 0.006
# train [9,  2000] acc: 1.000
# Adjusting learning rate of group 0 to 2.9261e-05.
# Adjusting learning rate of group 0 to 2.9020e-05.
# Adjusting learning rate of group 0 to 2.8780e-05.
# Adjusting learning rate of group 0 to 2.8542e-05.
# Adjusting learning rate of group 0 to 2.8304e-05.
# Adjusting learning rate of group 0 to 2.8067e-05.
# Adjusting learning rate of group 0 to 2.7832e-05.
# Adjusting learning rate of group 0 to 2.7597e-05.
# Adjusting learning rate of group 0 to 2.7364e-05.
# Adjusting learning rate of group 0 to 2.7131e-05.
# train [9,  2010] loss: 0.003
# train [9,  2010] acc: 1.000
# Adjusting learning rate of group 0 to 2.6899e-05.
# Adjusting learning rate of group 0 to 2.6669e-05.
# Adjusting learning rate of group 0 to 2.6439e-05.
# Adjusting learning rate of group 0 to 2.6210e-05.
# Adjusting learning rate of group 0 to 2.5983e-05.
# Adjusting learning rate of group 0 to 2.5756e-05.
# Adjusting learning rate of group 0 to 2.5531e-05.
# Adjusting learning rate of group 0 to 2.5306e-05.
# Adjusting learning rate of group 0 to 2.5082e-05.
# Adjusting learning rate of group 0 to 2.4860e-05.
# train [9,  2020] loss: 0.004
# train [9,  2020] acc: 1.000
# Adjusting learning rate of group 0 to 2.4638e-05.
# Adjusting learning rate of group 0 to 2.4417e-05.
# Adjusting learning rate of group 0 to 2.4198e-05.
# Adjusting learning rate of group 0 to 2.3979e-05.
# Adjusting learning rate of group 0 to 2.3762e-05.
# Adjusting learning rate of group 0 to 2.3545e-05.
# Adjusting learning rate of group 0 to 2.3329e-05.
# Adjusting learning rate of group 0 to 2.3115e-05.
# Adjusting learning rate of group 0 to 2.2901e-05.
# Adjusting learning rate of group 0 to 2.2688e-05.
# train [9,  2030] loss: 0.004
# train [9,  2030] acc: 1.000
# Adjusting learning rate of group 0 to 2.2477e-05.
# Adjusting learning rate of group 0 to 2.2266e-05.
# Adjusting learning rate of group 0 to 2.2057e-05.
# Adjusting learning rate of group 0 to 2.1848e-05.
# Adjusting learning rate of group 0 to 2.1640e-05.
# Adjusting learning rate of group 0 to 2.1434e-05.
# Adjusting learning rate of group 0 to 2.1228e-05.
# Adjusting learning rate of group 0 to 2.1023e-05.
# Adjusting learning rate of group 0 to 2.0820e-05.
# Adjusting learning rate of group 0 to 2.0617e-05.
# train [9,  2040] loss: 0.002
# train [9,  2040] acc: 1.000
# Adjusting learning rate of group 0 to 2.0416e-05.
# Adjusting learning rate of group 0 to 2.0215e-05.
# Adjusting learning rate of group 0 to 2.0015e-05.
# Adjusting learning rate of group 0 to 1.9817e-05.
# Adjusting learning rate of group 0 to 1.9619e-05.
# Adjusting learning rate of group 0 to 1.9423e-05.
# Adjusting learning rate of group 0 to 1.9227e-05.
# Adjusting learning rate of group 0 to 1.9032e-05.
# Adjusting learning rate of group 0 to 1.8839e-05.
# Adjusting learning rate of group 0 to 1.8646e-05.
# train [9,  2050] loss: 0.003
# train [9,  2050] acc: 1.000
# Adjusting learning rate of group 0 to 1.8454e-05.
# Adjusting learning rate of group 0 to 1.8264e-05.
# Adjusting learning rate of group 0 to 1.8074e-05.
# Adjusting learning rate of group 0 to 1.7886e-05.
# Adjusting learning rate of group 0 to 1.7698e-05.
# Adjusting learning rate of group 0 to 1.7511e-05.
# Adjusting learning rate of group 0 to 1.7326e-05.
# Adjusting learning rate of group 0 to 1.7141e-05.
# Adjusting learning rate of group 0 to 1.6957e-05.
# Adjusting learning rate of group 0 to 1.6775e-05.
# train [9,  2060] loss: 0.004
# train [9,  2060] acc: 1.000
# Adjusting learning rate of group 0 to 1.6593e-05.
# Adjusting learning rate of group 0 to 1.6413e-05.
# Adjusting learning rate of group 0 to 1.6233e-05.
# Adjusting learning rate of group 0 to 1.6054e-05.
# Adjusting learning rate of group 0 to 1.5877e-05.
# Adjusting learning rate of group 0 to 1.5700e-05.
# Adjusting learning rate of group 0 to 1.5524e-05.
# Adjusting learning rate of group 0 to 1.5350e-05.
# Adjusting learning rate of group 0 to 1.5176e-05.
# Adjusting learning rate of group 0 to 1.5004e-05.
# train [9,  2070] loss: 0.005
# train [9,  2070] acc: 1.000
# Adjusting learning rate of group 0 to 1.4832e-05.
# Adjusting learning rate of group 0 to 1.4661e-05.
# Adjusting learning rate of group 0 to 1.4492e-05.
# Adjusting learning rate of group 0 to 1.4323e-05.
# Adjusting learning rate of group 0 to 1.4156e-05.
# Adjusting learning rate of group 0 to 1.3989e-05.
# Adjusting learning rate of group 0 to 1.3823e-05.
# Adjusting learning rate of group 0 to 1.3659e-05.
# Adjusting learning rate of group 0 to 1.3495e-05.
# Adjusting learning rate of group 0 to 1.3332e-05.
# train [9,  2080] loss: 0.004
# train [9,  2080] acc: 1.000
# Adjusting learning rate of group 0 to 1.3171e-05.
# Adjusting learning rate of group 0 to 1.3010e-05.
# Adjusting learning rate of group 0 to 1.2851e-05.
# Adjusting learning rate of group 0 to 1.2692e-05.
# Adjusting learning rate of group 0 to 1.2534e-05.
# Adjusting learning rate of group 0 to 1.2378e-05.
# Adjusting learning rate of group 0 to 1.2222e-05.
# Adjusting learning rate of group 0 to 1.2068e-05.
# Adjusting learning rate of group 0 to 1.1914e-05.
# Adjusting learning rate of group 0 to 1.1761e-05.
# train [9,  2090] loss: 0.006
# train [9,  2090] acc: 1.000
# Adjusting learning rate of group 0 to 1.1610e-05.
# Adjusting learning rate of group 0 to 1.1459e-05.
# Adjusting learning rate of group 0 to 1.1309e-05.
# Adjusting learning rate of group 0 to 1.1161e-05.
# Adjusting learning rate of group 0 to 1.1013e-05.
# Adjusting learning rate of group 0 to 1.0867e-05.
# Adjusting learning rate of group 0 to 1.0721e-05.
# Adjusting learning rate of group 0 to 1.0576e-05.
# Adjusting learning rate of group 0 to 1.0433e-05.
# Adjusting learning rate of group 0 to 1.0290e-05.
# train [9,  2100] loss: 0.003
# train [9,  2100] acc: 1.000
# Adjusting learning rate of group 0 to 1.0149e-05.
# Adjusting learning rate of group 0 to 1.0008e-05.
# Adjusting learning rate of group 0 to 9.8684e-06.
# Adjusting learning rate of group 0 to 9.7298e-06.
# Adjusting learning rate of group 0 to 9.5922e-06.
# Adjusting learning rate of group 0 to 9.4556e-06.
# Adjusting learning rate of group 0 to 9.3200e-06.
# Adjusting learning rate of group 0 to 9.1854e-06.
# Adjusting learning rate of group 0 to 9.0518e-06.
# Adjusting learning rate of group 0 to 8.9192e-06.
# train [9,  2110] loss: 0.005
# train [9,  2110] acc: 1.000
# Adjusting learning rate of group 0 to 8.7876e-06.
# Adjusting learning rate of group 0 to 8.6570e-06.
# Adjusting learning rate of group 0 to 8.5274e-06.
# Adjusting learning rate of group 0 to 8.3988e-06.
# Adjusting learning rate of group 0 to 8.2712e-06.
# Adjusting learning rate of group 0 to 8.1446e-06.
# Adjusting learning rate of group 0 to 8.0190e-06.
# Adjusting learning rate of group 0 to 7.8944e-06.
# Adjusting learning rate of group 0 to 7.7708e-06.
# Adjusting learning rate of group 0 to 7.6482e-06.
# train [9,  2120] loss: 0.004
# train [9,  2120] acc: 1.000
# Adjusting learning rate of group 0 to 7.5266e-06.
# Adjusting learning rate of group 0 to 7.4060e-06.
# Adjusting learning rate of group 0 to 7.2864e-06.
# Adjusting learning rate of group 0 to 7.1678e-06.
# Adjusting learning rate of group 0 to 7.0502e-06.
# Adjusting learning rate of group 0 to 6.9336e-06.
# Adjusting learning rate of group 0 to 6.8180e-06.
# Adjusting learning rate of group 0 to 6.7035e-06.
# Adjusting learning rate of group 0 to 6.5899e-06.
# Adjusting learning rate of group 0 to 6.4773e-06.
# train [9,  2130] loss: 0.005
# train [9,  2130] acc: 1.000
# Adjusting learning rate of group 0 to 6.3657e-06.
# Adjusting learning rate of group 0 to 6.2551e-06.
# Adjusting learning rate of group 0 to 6.1455e-06.
# Adjusting learning rate of group 0 to 6.0369e-06.
# Adjusting learning rate of group 0 to 5.9293e-06.
# Adjusting learning rate of group 0 to 5.8228e-06.
# Adjusting learning rate of group 0 to 5.7172e-06.
# Adjusting learning rate of group 0 to 5.6126e-06.
# Adjusting learning rate of group 0 to 5.5090e-06.
# Adjusting learning rate of group 0 to 5.4064e-06.
# train [9,  2140] loss: 0.003
# train [9,  2140] acc: 1.000
# Adjusting learning rate of group 0 to 5.3048e-06.
# Adjusting learning rate of group 0 to 5.2042e-06.
# Adjusting learning rate of group 0 to 5.1047e-06.
# Adjusting learning rate of group 0 to 5.0061e-06.
# Adjusting learning rate of group 0 to 4.9085e-06.
# Adjusting learning rate of group 0 to 4.8119e-06.
# Adjusting learning rate of group 0 to 4.7163e-06.
# Adjusting learning rate of group 0 to 4.6218e-06.
# Adjusting learning rate of group 0 to 4.5282e-06.
# Adjusting learning rate of group 0 to 4.4356e-06.
# train [9,  2150] loss: 0.005
# train [9,  2150] acc: 1.000
# Adjusting learning rate of group 0 to 4.3440e-06.
# Adjusting learning rate of group 0 to 4.2535e-06.
# Adjusting learning rate of group 0 to 4.1639e-06.
# Adjusting learning rate of group 0 to 4.0753e-06.
# Adjusting learning rate of group 0 to 3.9877e-06.
# Adjusting learning rate of group 0 to 3.9012e-06.
# Adjusting learning rate of group 0 to 3.8156e-06.
# Adjusting learning rate of group 0 to 3.7310e-06.
# Adjusting learning rate of group 0 to 3.6475e-06.
# Adjusting learning rate of group 0 to 3.5649e-06.
# train [9,  2160] loss: 0.006
# train [9,  2160] acc: 1.000
# Adjusting learning rate of group 0 to 3.4833e-06.
# Adjusting learning rate of group 0 to 3.4028e-06.
# Adjusting learning rate of group 0 to 3.3232e-06.
# Adjusting learning rate of group 0 to 3.2446e-06.
# Adjusting learning rate of group 0 to 3.1671e-06.
# Adjusting learning rate of group 0 to 3.0905e-06.
# Adjusting learning rate of group 0 to 3.0149e-06.
# Adjusting learning rate of group 0 to 2.9404e-06.
# Adjusting learning rate of group 0 to 2.8668e-06.
# Adjusting learning rate of group 0 to 2.7942e-06.
# train [9,  2170] loss: 0.006
# train [9,  2170] acc: 1.000
# Adjusting learning rate of group 0 to 2.7227e-06.
# Adjusting learning rate of group 0 to 2.6521e-06.
# Adjusting learning rate of group 0 to 2.5826e-06.
# Adjusting learning rate of group 0 to 2.5140e-06.
# Adjusting learning rate of group 0 to 2.4464e-06.
# Adjusting learning rate of group 0 to 2.3799e-06.
# Adjusting learning rate of group 0 to 2.3143e-06.
# Adjusting learning rate of group 0 to 2.2498e-06.
# Adjusting learning rate of group 0 to 2.1862e-06.
# Adjusting learning rate of group 0 to 2.1237e-06.
# train [9,  2180] loss: 0.003
# train [9,  2180] acc: 1.000
# Adjusting learning rate of group 0 to 2.0621e-06.
# Adjusting learning rate of group 0 to 2.0016e-06.
# Adjusting learning rate of group 0 to 1.9420e-06.
# Adjusting learning rate of group 0 to 1.8835e-06.
# Adjusting learning rate of group 0 to 1.8259e-06.
# Adjusting learning rate of group 0 to 1.7694e-06.
# Adjusting learning rate of group 0 to 1.7138e-06.
# Adjusting learning rate of group 0 to 1.6593e-06.
# Adjusting learning rate of group 0 to 1.6057e-06.
# Adjusting learning rate of group 0 to 1.5532e-06.
# train [9,  2190] loss: 0.007
# train [9,  2190] acc: 1.000
# Adjusting learning rate of group 0 to 1.5016e-06.
# Adjusting learning rate of group 0 to 1.4511e-06.
# Adjusting learning rate of group 0 to 1.4016e-06.
# Adjusting learning rate of group 0 to 1.3530e-06.
# Adjusting learning rate of group 0 to 1.3055e-06.
# Adjusting learning rate of group 0 to 1.2589e-06.
# Adjusting learning rate of group 0 to 1.2134e-06.
# Adjusting learning rate of group 0 to 1.1688e-06.
# Adjusting learning rate of group 0 to 1.1253e-06.
# Adjusting learning rate of group 0 to 1.0828e-06.
# train [9,  2200] loss: 0.004
# train [9,  2200] acc: 1.000
# Adjusting learning rate of group 0 to 1.0412e-06.
# Adjusting learning rate of group 0 to 1.0007e-06.
# Adjusting learning rate of group 0 to 9.6117e-07.
# Adjusting learning rate of group 0 to 9.2263e-07.
# Adjusting learning rate of group 0 to 8.8510e-07.
# Adjusting learning rate of group 0 to 8.4857e-07.
# Adjusting learning rate of group 0 to 8.1304e-07.
# Adjusting learning rate of group 0 to 7.7851e-07.
# Adjusting learning rate of group 0 to 7.4498e-07.
# Adjusting learning rate of group 0 to 7.1245e-07.
# train [9,  2210] loss: 0.042
# train [9,  2210] acc: 0.988
# Adjusting learning rate of group 0 to 6.8092e-07.
# Adjusting learning rate of group 0 to 6.5040e-07.
# Adjusting learning rate of group 0 to 6.2087e-07.
# Adjusting learning rate of group 0 to 5.9235e-07.
# Adjusting learning rate of group 0 to 5.6482e-07.
# Adjusting learning rate of group 0 to 5.3830e-07.
# Adjusting learning rate of group 0 to 5.1278e-07.
# Adjusting learning rate of group 0 to 4.8825e-07.
# Adjusting learning rate of group 0 to 4.6473e-07.
# Adjusting learning rate of group 0 to 4.4221e-07.
# train [9,  2220] loss: 0.062
# train [9,  2220] acc: 0.988
# Adjusting learning rate of group 0 to 4.2069e-07.
# Adjusting learning rate of group 0 to 4.0018e-07.
# Adjusting learning rate of group 0 to 3.8066e-07.
# Adjusting learning rate of group 0 to 3.6214e-07.
# Adjusting learning rate of group 0 to 3.4463e-07.
# Adjusting learning rate of group 0 to 3.2811e-07.
# Adjusting learning rate of group 0 to 3.1260e-07.
# Adjusting learning rate of group 0 to 2.9809e-07.
# Adjusting learning rate of group 0 to 2.8457e-07.
# Adjusting learning rate of group 0 to 2.7206e-07.
# train [9,  2230] loss: 0.003
# train [9,  2230] acc: 1.000
# Adjusting learning rate of group 0 to 2.6055e-07.
# Adjusting learning rate of group 0 to 2.5004e-07.
# Adjusting learning rate of group 0 to 2.4054e-07.
# Adjusting learning rate of group 0 to 2.3203e-07.
# Adjusting learning rate of group 0 to 2.2452e-07.
# Adjusting learning rate of group 0 to 2.1802e-07.
# Adjusting learning rate of group 0 to 2.1251e-07.
# Adjusting learning rate of group 0 to 2.0801e-07.
# Adjusting learning rate of group 0 to 2.0450e-07.
# Adjusting learning rate of group 0 to 2.0200e-07.
# train [9,  2240] loss: 0.003
# train [9,  2240] acc: 1.000
# Adjusting learning rate of group 0 to 2.0050e-07.
# Adjusting learning rate of group 0 to 2.0000e-07.
# Adjusting learning rate of group 0 to 2.0050e-07.
# val 9 loss: 3.637
# val 9 acc: 0.996
# Best validation accuracy: 0.995986

# %% [markdown]
# Let's train!

# %%
plt.plot(training_losses, label='Training Loss')
plt.xlabel('Minibatch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss for ResNet18 with SGD On State Farm Data')
plt.savefig('StateFarm ResNet18 SGD Training Loss.png')
plt.show()

plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Validation Loss for ResNet18 with SGD On State Farm Data')
plt.savefig('StateFarm ResNet18 SGD Validation Loss.png')
plt.show()

# %% [markdown]
# Let's visualize our losses. For training loss, each point represents the training loss of a single minibatch. For our validation loss, each point is the total validation loss across our entire validation dataset per epoch.

# %%
plt.plot([acc.cpu() for acc in training_accuracy], label='Training Accuracy')
plt.xlabel('Minibatch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy for ResNet18 with SGD For State Farm Data')
plt.savefig('StateFarm ResNet18 SGD Training Accuracy.png')
plt.show()

plt.plot([acc.cpu() for acc in val_accuracy], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Validation Accuracy for ResNet18 with SGD For State Farm Data')
plt.savefig('StateFarm ResNet18 SGD Validation Accuracy.png')
plt.show()

# %% [markdown]
# Let's visualize our accuracy. For training accuracy, each point represents the training accuracy of a single minibatch. For our validation accuracy, each point is the validation accuracy across our entire validation dataset per epoch.

# %%
def test_accuracy(net):
    correct = 0.0
    
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = net(inputs)
            _, preds = torch.max(outputs, 1)
            
            correct += torch.sum(preds == labels.data)
    
    accuracy = correct / testing_split
    
    print(f'Test accuracy: {accuracy:4f}')
    
    return accuracy

# %%
test_accuracy(resnet)
# Out:
# Test accuracy: 0.987957
# tensor(0.9880, device='cuda:0')

# %% [markdown]
# Our best trained net has a pretty good accuracy.

# %%
import random

def demonstration(net):
    dataiter = iter(testloader)
    random_int = random.randrange(len(testloader))
    print(random_int)
    accuracy = 0.0
    for x in range(random_int + 1):
        images, classes = next(dataiter)
    inputs = images.to(device)
    labels = classes.to(device)
    
    outputs = net(inputs)
    _, preds = torch.max(outputs, 1)
    
    accuracy += torch.sum(preds == labels.data).item()
    print(accuracy / 4)
    preds = preds.to('cpu').numpy()
    imshow(torchvision.utils.make_grid(images), title=[key.get("c" + str(x)) for x in preds])
    plt.savefig('StateFarm demonstration.png')

# %%
demonstration(resnet)
# Out:
# 217
# 1.0

# %% [markdown]
# We see that our model can correctly label the actions of the driver from a random batch within our testing dataset.
